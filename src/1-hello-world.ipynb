# %%
import setup  # notebooks/setup.py
setup.init()

# %%
from django.contrib.auth import get_user_model

User = get_user_model()

# %%
User.objects.all()
# Out:
# <QuerySet [<User: ashish>]>

# %%
User.objects.create(
    username="ethan",
)
# Out:
# <User: ethan>

# %%
User.objects.all()
# Out:
# <QuerySet [<User: ashish>, <User: ethan>]>
