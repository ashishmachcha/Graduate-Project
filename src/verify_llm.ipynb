# %%
import setup  # notebooks/setup.py
setup.init()

# %%
from AI.llm import get_groq_model

# %%
model = get_groq_model()

# %%
ashish=model.invoke("can you create a django to do list project give me the code").content
